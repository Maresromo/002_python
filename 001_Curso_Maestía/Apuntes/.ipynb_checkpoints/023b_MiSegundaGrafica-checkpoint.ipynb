# %%
import pandas as pd
import glob as glob
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

# %%
tmx = pd.read_csv("./data/tmix_complete.csv",
       index_col=0, parse_dates=True)
tmx.plot()
# Out:
# <Axes: xlabel='TIMESTAMP'>

# %%
fig =plt.figure(layout='constrained')

gs = GridSpec(3, 3, figure=fig)           #Aca se crea la maya

ax2 = fig.add_subplot(gs[1:2,:-1])
ax1 = fig.add_subplot(gs[0,:-1],sharex=ax2)          #Aca indica de donde a donde va la grafica, aca esta en la posicion 0 y va desde el inicio hasta el final
# ax3 = fig.add_subplot(gs[:2,2:])

# ax1.plot(tmx.Temp_Avg)
# ax2.plot(tmx.Rad_Avg)
# ax3.plot(tmx.Rad_Avg)

plt.setp(ax1.get_xticklabels(), visible=False)

plt.show()
