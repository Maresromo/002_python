# %%
import pandas as pd

# %%
f = "../data/Temixco_2018_10Min.csv"
tmx = pd.read_csv(f)
tmx.info()     #Faltan datos en 1 y 2, porque tienen menos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52560 entries, 0 to 52559
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    52560 non-null  object
#  1   Ib      52423 non-null  float64
#  2   Ig      52423 non-null  float64
#  3   To      52560 non-null  float64
#  4   RH      52560 non-null  float64
#  5   WS      52560 non-null  float64
#  6   WD      52560 non-null  float64
#  7   P       52560 non-null  float64
# dtypes: float64(7), object(1)
# memory usage: 3.2+ MB

# %%
tmx.describe()    #NOTA cabe destacar que los valores maximos son dudosos, yaq ue se aproximan mucho a la constante solar
# Out:
#                  Ib            Ig            To            RH           WS  \
# count  52423.000000  52423.000000  52560.000000  52560.000000  52560.00000
# mean     236.742726    257.414344     22.838098     45.152827      1.90520
# std      327.983721    345.976954      4.443339     19.426263      1.04411
# min        0.000000      0.000000      8.160000      5.648000      0.05000
# 25%        0.001000      0.000000     19.350000     29.770000      1.18000
# 50%        0.260000      3.293000     22.670000     42.600000      1.78500
# 75%      542.300000    533.900000     26.030000     59.280000      2.46000
# max     1021.000000   1348.000000     35.870000     97.700000     14.86000
#
#                  WD             P
# count  52560.000000  52560.000000
# mean     210.734453  87591.151598
# std      109.276328    245.715965
# min        0.000000  86772.650000
# 25%      134.675000  87429.500000
# 50%      211.900000  87595.090000
# 75%      319.800000  87760.647500
# ...

# %%
f = "../data/Temixco_2018_10Min.csv"
tmx = pd.read_csv(f,index_col=0,parse_dates=True)   #Parse convierte el formato a datatime, antes era objeto, lo que hace es adivinar el formato de tiempo
tmx                                                 #generalmente no se equivoca
# Out:
#                         Ib   Ig     To     RH     WS     WD         P
# time
# 2018-01-01 00:00:00    NaN  NaN  18.70  36.34  1.422  316.0  87864.11
# 2018-01-01 00:10:00  0.002  0.0  18.95  35.29  1.008  283.7  87876.37
# 2018-01-01 00:20:00  0.170  0.0  18.94  35.43  1.565  326.0  87888.64
# 2018-01-01 00:30:00  0.371  0.0  18.77  35.89  2.175  354.5  87887.21
# 2018-01-01 00:40:00  0.305  0.0  18.81  36.34  1.902  348.0  87886.91
# ...                    ...  ...    ...    ...    ...    ...       ...
# 2018-12-31 23:10:00  0.125  0.0  18.51  47.29  1.715  332.2  87484.32
# 2018-12-31 23:20:00  0.000  0.0  18.26  48.02  1.703  320.5  87470.70
# 2018-12-31 23:30:00  0.044  0.0  18.39  46.84  2.887  335.7  87455.03
# 2018-12-31 23:40:00  0.170  0.0  17.99  47.85  1.528  358.8  87470.02
# 2018-12-31 23:50:00  0.003  0.0  17.75  49.65  0.598  322.3  87467.29
#
# [52560 rows x 7 columns]

# %%
f = "../data/Temixco_2018_10Min.csv"
tmx = pd.read_csv(f)   #Parse convierte el formato a datatime, antes era objeto, lo que hace es adivinar el formato de tiempo
tmx.time = pd.to_datetime(tmx.time,format="%Y-%m-%d %H:%M:%S")                          #Aca le especificamos el formato
# tmx.time = pd.to_datetime(tmx.time,format="%Y-%m-%d %H:%M:%S")
tmx.set_index("time",inplace = True)
tmx
# Out:
#                         Ib   Ig     To     RH     WS     WD         P
# time
# 2018-01-01 00:00:00    NaN  NaN  18.70  36.34  1.422  316.0  87864.11
# 2018-01-01 00:10:00  0.002  0.0  18.95  35.29  1.008  283.7  87876.37
# 2018-01-01 00:20:00  0.170  0.0  18.94  35.43  1.565  326.0  87888.64
# 2018-01-01 00:30:00  0.371  0.0  18.77  35.89  2.175  354.5  87887.21
# 2018-01-01 00:40:00  0.305  0.0  18.81  36.34  1.902  348.0  87886.91
# ...                    ...  ...    ...    ...    ...    ...       ...
# 2018-12-31 23:10:00  0.125  0.0  18.51  47.29  1.715  332.2  87484.32
# 2018-12-31 23:20:00  0.000  0.0  18.26  48.02  1.703  320.5  87470.70
# 2018-12-31 23:30:00  0.044  0.0  18.39  46.84  2.887  335.7  87455.03
# 2018-12-31 23:40:00  0.170  0.0  17.99  47.85  1.528  358.8  87470.02
# 2018-12-31 23:50:00  0.003  0.0  17.75  49.65  0.598  322.3  87467.29
#
# [52560 rows x 7 columns]

# %%
tmx[["Ib","Ig"]].plot(subplots=True,figsize=(12,5))        #se aborta con ii
# Out:
# array([<Axes: xlabel='time'>, <Axes: xlabel='time'>], dtype=object)
# Error in callback <function flush_figures at 0x00000154A2C99DA0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
# ...

# %%
fecha = [
    "2024-01-01",
    "2024-02-01"
]

fecha = [pd.to_datetime(f) for f in fecha]
fecha
# Out:
# [Timestamp('2024-01-01 00:00:00'), Timestamp('2024-02-01 00:00:00')]
