# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from dateutil.parser import parse

# %%
f = '../data/Temixco_2018_10Min.csv'
tmx = pd.read_csv(f,index_col=0,parse_dates=True)
tmx
# Out:
#                         Ib   Ig     To     RH     WS     WD         P
# time
# 2018-01-01 00:00:00    NaN  NaN  18.70  36.34  1.422  316.0  87864.11
# 2018-01-01 00:10:00  0.002  0.0  18.95  35.29  1.008  283.7  87876.37
# 2018-01-01 00:20:00  0.170  0.0  18.94  35.43  1.565  326.0  87888.64
# 2018-01-01 00:30:00  0.371  0.0  18.77  35.89  2.175  354.5  87887.21
# 2018-01-01 00:40:00  0.305  0.0  18.81  36.34  1.902  348.0  87886.91
# ...                    ...  ...    ...    ...    ...    ...       ...
# 2018-12-31 23:10:00  0.125  0.0  18.51  47.29  1.715  332.2  87484.32
# 2018-12-31 23:20:00  0.000  0.0  18.26  48.02  1.703  320.5  87470.70
# 2018-12-31 23:30:00  0.044  0.0  18.39  46.84  2.887  335.7  87455.03
# 2018-12-31 23:40:00  0.170  0.0  17.99  47.85  1.528  358.8  87470.02
# 2018-12-31 23:50:00  0.003  0.0  17.75  49.65  0.598  322.3  87467.29
#
# [52560 rows x 7 columns]

# %%
fig, ax = plt.subplots(2, figsize=(12,4), sharex=True)

f1 = parse("2018-01-13")
f2 = f1 + pd.Timedelta('3D')

ax[0].plot(tmx.Ig, label='Ig')
ax[1].plot(tmx.To, label='To')

ax[0].legend()
ax[1].legend()

ax[0].set_xlim(f1,f2)
# Out:
# (np.float64(17544.0), np.float64(17547.0))

# %%
columnas=tmx.columns
Is = [columna for columna in columnas if "I" in columna]
Is   #Is es una lista que contiene los nombres de las series que queremos visualizar, es util para automatizar
# Out:
# ['Ib', 'Ig']

# %%
fig, ax = plt.subplots(len(Is), figsize=(10,4), sharex=True)   #con len(Is) nos cuenta cuantas series vamos a graficar

for i,I in enumerate(Is):        #con enumerate nos da i= indice, I=nombre del objeto
    ax[i].plot(tmx[I],label=I)

for eje in ax:                   #Aca graficamos todas las series que tenemos en ax
    eje.legend()
