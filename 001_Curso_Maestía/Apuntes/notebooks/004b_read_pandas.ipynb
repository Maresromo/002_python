# %%
#pip install openpyxl   
#Esto es para poder importar datos de excel

# %%
import pandas as pd

# %%
# %%timeit
f = "../data/xy.xlsx"
pd.read_excel(f,index_col=0)
# Out:
# 6.44 ms ± 450 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
f = "../data/xy.xlsx"
pd.read_excel(f,usecols=[1,2])
# Out:
# 15.4 ms ± 6.45 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
    #Es 8 veces mas rapido que si se importa desde excel
f = "../data/xy.csv"
xy = pd.read_csv(f)
xy
# Out:
#     x     y
# 0   1  10.0
# 1   2   2.0
# 2   3   3.0
# 3   4   4.0
# 4   5   5.0
# 5   6   6.0
# 6   7  73.0
# 7   8  34.0
# 8   9  23.0
# 9  10  -1.0

# %%
xy.plot()
# Out:
# <Axes: >

# %%
xy.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
xy[['y','x']].plot(subplots=True)  #Para cambiar de orden
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
    #Agarra el indice como el eje ordenado
f = "../data/xy.csv"
xy = pd.read_csv(f,index_col=0)
xy.plot()
# Out:
# <Axes: xlabel='x'>

# %%
f = '../data/xy_tabulado.csv'
tabulado = pd.read_csv(f,sep="\t",usecols=[1,2],index_col=0)  #Como el separador es un tabulador, lo tenemos que identificar
tabulado                                                       #Ademas, si marcamos que usaremos algunas columnas, (usecols), depues la columna 0 sera la primera de las que escogiste
# Out:
#        y
# x
# 1   10.0
# 2    2.0
# 3    3.0
# 4    4.0
# 5    5.0
# 6    6.0
# 7   73.0
# 8   34.0
# 9   23.0
# 10  -1.0

# %%
    #Es 8 veces mas rapido que si se importa desde excel
f = "../data/xy.csv"
xy = pd.read_csv(f)
xy
# Out:
#     x     y
# 0   1  10.0
# 1   2   2.0
# 2   3   3.0
# 3   4   4.0
# 4   5   5.0
# 5   6   6.0
# 6   7  73.0
# 7   8  34.0
# 8   9  23.0
# 9  10  -1.0

# %%
xy.y**2   #Se pueden hacer operaciones, son mascaras
# Out:
# 0     100.0
# 1       4.0
# 2       9.0
# 3      16.0
# 4      25.0
# 5      36.0
# 6    5329.0
# 7    1156.0
# 8     529.0
# 9       1.0
# Name: y, dtype: float64

# %%
xy.y*xy.x.mean()   #Se pueden hacer operaciones, son mascaras
# Out:
# 0     55.0
# 1     11.0
# 2     16.5
# 3     22.0
# 4     27.5
# 5     33.0
# 6    401.5
# 7    187.0
# 8    126.5
# 9     -5.5
# Name: y, dtype: float64

# %%
promedio=(xy.mean())
promedio
# Out:
# x     5.5
# y    15.9
# dtype: float64

# %%
xy.x.mean(),xy.y.mean()
# Out:
# (np.float64(5.5), np.float64(15.9))

# %%
promy = xy.y.mean()       #Asi podemos agregar series al dataframe, si no existe la crea, pero si ya existe, la sobrescribe
xy["promy"]=promy
xy
# Out:
#     x     y  promy
# 0   1  10.0   15.9
# 1   2   2.0   15.9
# 2   3   3.0   15.9
# 3   4   4.0   15.9
# 4   5   5.0   15.9
# 5   6   6.0   15.9
# 6   7  73.0   15.9
# 7   8  34.0   15.9
# 8   9  23.0   15.9
# 9  10  -1.0   15.9
